# %% [markdown]
# <a href="https://colab.research.google.com/github/dmak007/level-up-advanced-python/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
# @title List available models
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.0-flash',
#  'google/gemini-2.0-flash-lite',
#  'google/gemini-2.5-flash',
#  'google/gemini-2.5-flash-lite',
#  'google/gemini-2.5-pro',
#  'google/gemma-3-12b',
#  'google/gemma-3-1b',
#  'google/gemma-3-27b',
#  'google/gemma-3-4b']

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text("How to split the terminal horizotnally in tmux")
print(response)
# Out:
# To split the terminal in **tmux**, you use a prefix key combination (by default, **`Ctrl + b`**), release it, and then press the split key.
#
# Because "horizontal" can mean different things to different people (a horizontal line splitting top/bottom, or splitting side-by-side), here are both ways:
#
# ### 1. Split into Top and Bottom (Horizontal line)
# To split the screen so you have one pane on top and one on the bottom:
# * Press **`Ctrl + b`**, release them, and then press **`"`** (double quote / Shift + ').
#
# ### 2. Split into Left and Right (Vertical line)
# To split the screen side-by-side:
# * Press **`Ctrl + b`**, release them, and then press **`%`** (percent / Shift + 5).
#
# ---
#
# ### Command Line Method
# If you are already inside a tmux session and want to type a command to split the window:
#
# * For **top/bottom** split:
#   ```bash
#   tmux split-window -v
#   ```
# * For **left/right** split:
#   ```bash
#   tmux split-window -h
#   ```
#
# ---
#
# ### How to navigate between the splits
# Once split, you can move your cursor between the panes:
# * Press **`Ctrl + b`**, then use the **Arrow Keys** to move in the direction of the pane you want to active.
# * To close the active pane, type `exit` or press **`Ctrl + d`**.

# %%
# @title Choose a different model
from google.colab import ai

response = ai.generate_text("what does end argument in print function do in python")
print(response)
# Out:
# In Python, the `end` argument in the `print()` function specifies **what to print at the very end of the output**.
#
# By default, the `print()` function ends with a newline character (`\n`), which is why every `print()` statement starts on a new line. By using the `end` argument, you can change this behavior to end with a space, a comma, nothing at all, or any other string.
#
# ---
#
# ### 1. Default Behavior (Without `end`)
# By default, `end` is set to `'\n'` (newline).
#
# ```python
# print("Hello")
# print("World")
# ```
# **Output:**
# ```text
# Hello
# World
# ```
#
# ---
#
# ### 2. Using `end` with a Space
# If you want to print multiple items on the same line separated by a space, set `end=" "`.
#
# ```python
# print("Hello", end=" ")
# print("World")
# ```
# **Output:**
# ```text
# Hello World
# ```
#
# ---
#
# ### 3. Using `end` with an Empty String
# If you want to join the outputs together with absolutely no spaces or newlines, set `end=""`.
#
# ```python
# print("Py", end="")
# print("thon")
# ```
# **Output:**
# ```text
# Python
# ```
#
# ---
#
# ### 4. Using Custom Characters
# You can use any string of characters for the `end` argument.
#
# ```python
# print("Step 1", end=" -> ")
# print("Step 2", end=" -> ")
# print("Finished!")
# ```
# **Output:**
# ```text
# Step 1 -> Step 2 -> Finished!
# ```
#
# ---
#
# ### Common Use Case: Printing inside a loop
# The `end` argument is extremely useful when printing elements of a list or loop on a single line.
#
# ```python
# numbers = [1, 2, 3, 4, 5]
#
# for num in numbers:
#     print(num, end=", ")
# ```
# **Output:**
# ```text
# 1, 2, 3, 4, 5,
# ```

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Does $# in bash tells the number of args passed into the script. Does it mean anythin else elg args to the local fucnti. What does it call. Give a list of common constucs like this to remember.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# Yes, you are entirely correct on both counts.
#
# Here are the detailed answers to your questions, what these variables are called, and a "cheat sheet" of the most common ones to remember.
#
# ---
#
# ### 1. Does `$#` mean the number of arguments?
# **Yes.**
# * **At the script level:** It represents the number of arguments passed to the script.
# * **Inside a function:** It represents the number of arguments passed **to that specific function**, overriding the script-level count while inside that function.
#
# #### Example of scope:
# ```bash
# #!/bin/bash
#
# echo "Script argument count: $#" # Counts arguments passed to the script
#
# my_function() {
#     echo "Function argument count: $#" # Counts arguments passed to the function
# }
#
# # Call the function with 2 arguments
# my_function "apple" "banana"
# ```
#
# If you run `./script.sh one two three`, the output will be:
# ```text
# Script argument count: 3
# Function argument count: 2
# ```
#
# ---
#
# ### 2. What are these called?
# In Bash, these are formally called **Special Parameters** (or **Special Variables**).
#
# ---
#
# ### 3. Cheat Sheet of Common Special Parameters
#
# Here is a list of the most important Bash special parameters you should memorize:
#
# | Parameter | What it represents | Common Use Case |
# | :--- | :--- | :--- |
# | **`$#`** | Number of arguments passed. | Checking if the user forgot to provide arguments (e.g., `if [ $# -eq 0 ]`). |
# | **`$0`** | The name of the script being executed. | Printing usage instructions (e.g., `echo "Usage: $0 [file]"`). |
# | **`$1`, `$2`...** | The 1st, 2nd, etc., argument passed. | Accessing specific inputs. Note: For numbers above 9, use braces: `${10}`. |
# | **`$@`** | **All** arguments as separate words. | Best way to loop through all arguments safely: `for arg in "$@"; do` |
# | **`$*`** | **All** arguments as a single string. | Rarely used; usually better to use `$@` to avoid spacing/quoting issues. |
# | **`$?`** | The exit status of the **last executed command**. | Error checking. `0` means success; any other number means failure. |
# | **`$$`** | Process ID (PID) of the current shell. | Useful for creating unique temporary files (e.g., `/tmp/tempfile.$$`). |
# | **`$!`** | PID of the last **background** job. | Waiting for a background task to finish (`wait $!`). |
# | **`$_`** | The last argument of the previous command. | Handy in the interactive terminal to reuse the last argument. |
#
# ---
#
# ### A Crucial Trick: `"$@"` vs `"$*"`
#
# This is a very common point of confusion. Always default to using **`"$@"`** (with double quotes).
#
# * **`"$@"`** expands to: `"$1"` `"$2"` `"$3"` (preserves spaces in arguments).
# * **`"$*"`** expands to: `"$1 $2 $3"` (merges everything into one giant word).
#
# **Example:**
# If you pass two arguments to a script: `"blue berry"` and `"pie"`
# * `"$@"` treats them as **2** items: `blue berry` and `pie`.
# * `"$*"` treats them as **1** item: `blue berry pie`.None

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
from google.colab import ai

wrapper = LineWrapper()
for chunk in ai.generate_text('Write a bash script that runs the following script until it fails and captures its standard output and error streams.', stream=True):
  wrapper.print(chunk)
# Out:
# Here is a robust Bash script that will run your target script (or any command)
# in a loop until it fails.
#
# It captures both **stdout** and **stderr** (combined chronologically), displays
# them when the failure occurs, and saves the output to a log file for your
# analysis. It also includes a cleanup mechanism if you decide to stop it early
# using `Ctrl+C`.
#
# ### The Bash Script (`run_until_fail.sh`)
#
# ```bash
# #!/bin/bash
#
# # Check if a command was passed as an argument
# if [ "$#" -lt 1 ]; then
# echo "Usage: $0 <script_ or_command> [arguments...]"
# echo "Example: $0 ./my_script.sh --verbose "
# exit 1
# fi
#
# COMMAND=("$@")
# TEMP_LOG=$(mktemp)
# FAIL_LOG="failure_report.log"
# count=0
#
# # Cleanup temporary file on exit (even if interrupted with Ctrl+C)
# cleanup() {
# rm -f "$TEMP_LOG"
# exit 1
# }
# trap cleanup INT TERM
#
# echo "Running '${COMMAND[*]}' until it fails..."
# echo "--------------------------------------------------"
#
# while true; do
# ((count++))
#
# # Run the command, redirecting both stdout and stderr to the temp log
# "${COMMAND[@]}" > "$TEMP_LOG" 2>&1
# EXIT_CODE=$?
#
# # Check if the command failed (exit code is non-zero)
# if [ $EXIT_CODE -ne 0 ]; then
# echo -e "\n\n=== FAILURE DETECTED ON RUN #$count (Exit Code: $EXIT_CODE) ==="
#
# # Save the captured output to a permanent file
# cp "$TEMP_LOG" "$ FAIL_LOG"
#
# echo "Output saved to: $FAIL_LOG"
# echo "=== Output details below ==="
# echo "--------------------------------------------------"
# cat "$FAIL_LOG"
# echo " --------------------------------------------------"
#
# # Clean up and exit with the command's actual failure code
# rm -f "$TEMP_LOG"
# exit $EXIT_CODE
# fi
#
# # Print progress on the same line to keep the terminal clean
# echo -ne "Iteration $count: SUCCESS\r"
# done
# ```
#
# ### How to use it:
#
# 1. **Save the script**: Save the code above into a file, for example, `run_
# until_fail.sh`.
# 2. **Make it executable**:
# ```bash
# chmod +x run_until _fail.sh
# ```
# 3. **Run your target script**: Pass your script (and any arguments it needs)
# directly to this script:
# ```bash
# ./run_until_fail.sh ./your_script .sh
# ```
#
# ### Features:
# * **Real-time Counter:** It shows `Iteration X: SUCCESS` on a single line so it
# doesn't clutter your terminal while waiting for a failure.
# * **Chronological Log:** By using `> "$TEMP_LOG" 2>&1`, it captures stdout and
# stderr together in the exact order they occurred.
# * **Safe Termination:** If you get tired of waiting and press `Ctrl+C`, the
# script cleanly deletes its temporary files.
# * **Preserves Exit Code:** The wrapper script exits with the exact same non-zero
# exit code that your script failed with.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_514/3345499309.py in <cell line: 0>()
#       4 wrapper = LineWrapper()
#       5 for chunk in ai.generate_text('Write a bash script that runs the following script until it fails and captures its standard output and error streams.', stream=True):
# ----> 6   wrapper.print(chunk)
#
# /tmp/ipykernel_514/930987517.py in print(self, text_chunk)
#      10     def print(self, text_chunk):
#      11         i = 0
# ---> 12         n = len(text_chunk)
#      13         while i < n:
#      14             start_index = i
#
# TypeError: object of type 'NoneType' has no len()

# %%
# @title Formatted streaming example
from google.colab import ai

ai.generate_text("what the differnce in bash betwee if [ and if [[. Dont use markdown in answer. Fomrat the output in parapgahs")
# Out:
# 'The primary difference between the single bracket and the double bracket in Bash is that the single bracket is a POSIX-compliant command, while the double bracket is an enhanced keyword specific to Bash and a few other modern shells. Because the single bracket is actually a synonym for the standard test command, it is highly portable and will work across almost all Unix-like shells. The double bracket is a built-in shell construct that offers more features and safer behavior, but it is not portable to basic POSIX-compliant shells like dash.\n\nOne of the most practical differences lies in how they handle variables. When using the single bracket, variables must be enclosed in double quotes. If a variable is empty or contains spaces, the single bracket will fail with a syntax error because the shell performs word splitting on the variable before executing the command. The double bracket does not perform word splitting or filename expansion, which means you can safely use variables without double quotes and avoid unexpected crashes.\n\nThe syntax for logical operations also differs significantly between the two. Inside single brackets, you must use the older hyphen-a and hyphen-o operators for logical AND and OR operations, or you must exit the bracket and chain multiple tests together using shell operators. Double brackets allow you to use the standard double-ampersand and double-pipe operators directly inside the evaluation block, which makes the code much cleaner and more familiar to programmers of other languages.\n\nAdditionally, double brackets offer advanced pattern matching capabilities that are completely missing from single brackets. With double brackets, you can perform wildcard glob matching using the double-equals operator, and you can use regular expressions with the equals-tilde operator. Single brackets only support basic string and numeric comparisons, requiring you to use external tools like grep if you need to perform complex pattern matching.'
